# %% [markdown]
# Decided to improve the prompt before fine-tuning, by providing more few-shot examples and definitions. As you can see, it improved stability much.

# %%
import json
import ollama

# %%
SYSTEM_PROMPT = ""
with open("../../global_system_prompt.txt", "r", encoding="utf-8") as f:
    SYSTEM_PROMPT = f.read()

# %%
from collections import Counter

def get_structure(json_data):
    try:
        data = json.loads(json_data)
        return {
            "atoms_count": len(data.get("atoms", [])),
            "rules_count": len(data.get("rules", [])),
            "strict_rules": len([r for r in data.get("rules", []) if r.get("type") == "strict"]),
            "defeasible_rules": len([r for r in data.get("rules", []) if r.get("type") == "defeasible"]),
            "attacks_count": len(data.get("attacks", [])),
            "attack_types": Counter([a.get("type") for a in data.get("attacks", [])])
        }
    except:
        return "Invalid JSON"

# %%
prompts=[]
with open("data/variance/prompts.txt", "r") as f:
    prompts = f.read()
for i in prompts.split("@"):
    outputs=[]
    print("Prompt:", i)
    for j in range(5):
        response = ollama.chat(
            model="qwen2.5:14b",
            format="json",
            messages=[
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user", "content": i}
            ],
            options={"temperature": 0}
        )
        outputs.append(response["message"]["content"].strip())
        print("Output", j+1, "processed.")
    for k in outputs:
        print(get_structure(k))
# Out:
# Prompt: John is guilty of trespassing because he entered the private property without permission. However, John claims he was invited by the owner, which means he is not guilty of trespassing.
#
# Output 1 processed.
# Output 2 processed.
# Output 3 processed.
# Output 4 processed.
# Output 5 processed.
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# Prompt:
# The security footage shows a person in a red hat stealing the bike, so the thief wore a red hat. But the camera was low-resolution and the colors are distorted, so the footage cannot reliably identify the color of the hat.
#
# Output 1 processed.
# Output 2 processed.
# Output 3 processed.
# Output 4 processed.
# Output 5 processed.
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# Prompt:
# Professor X says that climate change is stopping because global temperatures decreased this year. However, the data showing a temperature decrease was fabricated by an intern.
#
# Output 1 processed.
# Output 2 processed.
# Output 3 processed.
# Output 4 processed.
# Output 5 processed.
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 2, 'attack_types': Counter({'undermine': 1, 'undercut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 2, 'attack_types': Counter({'undermine': 1, 'undercut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 2, 'attack_types': Counter({'undermine': 1, 'undercut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 2, 'attack_types': Counter({'undermine': 1, 'undercut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 2, 'attack_types': Counter({'undermine': 1, 'undercut': 1})}
# Prompt:
# Oxygen is required for fire. This room is a vacuum, meaning there is no oxygen here. Therefore, a fire cannot be started in this room.
#
# Output 1 processed.
# Output 2 processed.
# Output 3 processed.
# Output 4 processed.
# Output 5 processed.
# {'atoms_count': 4, 'rules_count': 1, 'strict_rules': 1, 'defeasible_rules': 0, 'attacks_count': 0, 'attack_types': Counter()}
# {'atoms_count': 4, 'rules_count': 1, 'strict_rules': 1, 'defeasible_rules': 0, 'attacks_count': 0, 'attack_types': Counter()}
# {'atoms_count': 4, 'rules_count': 1, 'strict_rules': 1, 'defeasible_rules': 0, 'attacks_count': 0, 'attack_types': Counter()}
# {'atoms_count': 4, 'rules_count': 1, 'strict_rules': 1, 'defeasible_rules': 0, 'attacks_count': 0, 'attack_types': Counter()}
# {'atoms_count': 4, 'rules_count': 1, 'strict_rules': 1, 'defeasible_rules': 0, 'attacks_count': 0, 'attack_types': Counter()}
# Prompt:
# The patient has a fever, so they have an infection. If they have an infection, they should take antibiotics. However, the patient is allergic to penicillin, so penicillin should not be used as the antibiotic.
# Output 1 processed.
# Output 2 processed.
# Output 3 processed.
# Output 4 processed.
# Output 5 processed.
# {'atoms_count': 5, 'rules_count': 3, 'strict_rules': 2, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 5, 'rules_count': 3, 'strict_rules': 2, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 5, 'rules_count': 3, 'strict_rules': 2, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 5, 'rules_count': 3, 'strict_rules': 2, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 5, 'rules_count': 3, 'strict_rules': 2, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}

# %%
prompts=[]
with open("data/stability/prompts.txt", "r") as f:
    prompts = f.read()
ct=1
for i in prompts.split(";"):
    outputs=[]
    print("Prompt set ", ct, "\n")
    ct2=1
    for j in i.split("@"):
        response = ollama.chat(
            model="qwen2.5:14b",
            format="json",
            messages=[
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user", "content": j}
            ],
            options={"temperature": 0}
        )
        outputs.append(response["message"]["content"].strip())
        print("Output", (ct-1)*5+ct2, "processed.")
        ct2+=1
    ct+=1
    for k in outputs:
        print(get_structure(k))
# Out:
# Prompt set  1
#
# Output 1 processed.
# Output 2 processed.
# Output 3 processed.
# Output 4 processed.
# Output 5 processed.
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# Prompt set  2
#
# Output 6 processed.
# Output 7 processed.
# Output 8 processed.
# Output 9 processed.
# Output 10 processed.
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# Prompt set  3
#
# Output 11 processed.
# Output 12 processed.
# Output 13 processed.
# Output 14 processed.
# Output 15 processed.
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undermine': 1})}
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undermine': 1})}
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undermine': 1})}
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undermine': 1})}
# {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undermine': 1})}
# Prompt set  4
#
# Output 16 processed.
# Output 17 processed.
# Output 18 processed.
# Output 19 processed.
# Output 20 processed.
# {'atoms_count': 4, 'rules_count': 1, 'strict_rules': 1, 'defeasible_rules': 0, 'attacks_count': 0, 'attack_types': Counter()}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 0, 'attack_types': Counter()}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 2, 'defeasible_rules': 0, 'attacks_count': 0, 'attack_types': Counter()}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 2, 'defeasible_rules': 0, 'attacks_count': 0, 'attack_types': Counter()}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 0, 'attack_types': Counter()}
# Prompt set  5
#
# Output 21 processed.
# Output 22 processed.
# Output 23 processed.
# Output 24 processed.
# Output 25 processed.
# {'atoms_count': 5, 'rules_count': 3, 'strict_rules': 1, 'defeasible_rules': 2, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 5, 'rules_count': 3, 'strict_rules': 1, 'defeasible_rules': 2, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 3, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 6, 'rules_count': 3, 'strict_rules': 1, 'defeasible_rules': 2, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}

# %%
prompts=[]
valid_outputs=[]
with open("data/correctness/prompts.txt", "r") as f:
    prompts = f.read()
with open("data/correctness/outputs.txt", "r") as f:
    valid_outputs = f.read()
ct=0
for i in prompts.split("@"):
    print("Prompt:", i)
    response = ollama.chat(
        model="qwen2.5:14b",
        format="json",
        messages=[
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": i}
        ],
        options={"temperature": 0}
    )
    print("Computed output: ",get_structure(response["message"]["content"].strip()))
    print("Valid output: ", get_structure(valid_outputs.split("@")[ct]),"\n")
# Out:
# Prompt: John is guilty of trespassing because he entered the private property without permission. However, John claims he was invited by the owner, which means he is not guilty of trespassing.
#
# Computed output:  {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 1, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# Valid output:  {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
#
# Prompt:
# The security footage shows a person in a red hat stealing the bike, so the thief wore a red hat. But the camera was low-resolution and the colors are distorted, so the footage cannot reliably identify the color of the hat.
#
# Computed output:  {'atoms_count': 3, 'rules_count': 1, 'strict_rules': 0, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# Valid output:  {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
#
# Prompt:
# Professor X says that climate change is stopping because global temperatures decreased this year. However, the data showing a temperature decrease was fabricated by an intern.
#
# Computed output:  {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 2, 'attack_types': Counter({'undermine': 1, 'undercut': 1})}
# Valid output:  {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
#
# Prompt:
# Oxygen is required for fire. This room is a vacuum, meaning there is no oxygen here. Therefore, a fire cannot be started in this room.
#
# Computed output:  {'atoms_count': 4, 'rules_count': 1, 'strict_rules': 1, 'defeasible_rules': 0, 'attacks_count': 0, 'attack_types': Counter()}
# Valid output:  {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
#
# Prompt:
# The patient has a fever, so they have an infection. If they have an infection, they should take antibiotics. However, the patient is allergic to penicillin, so penicillin should not be used as the antibiotic.
# Computed output:  {'atoms_count': 5, 'rules_count': 3, 'strict_rules': 2, 'defeasible_rules': 1, 'attacks_count': 1, 'attack_types': Counter({'undercut': 1})}
# Valid output:  {'atoms_count': 4, 'rules_count': 2, 'strict_rules': 0, 'defeasible_rules': 2, 'attacks_count': 1, 'attack_types': Counter({'rebut': 1})}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# All of the data and results can be found in the corresponding directory in the data folder.
